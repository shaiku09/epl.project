# %% [markdown]
# # WEEK 2

# %%
# comment to be made

# %%
a = 1

# %%
a
# Out:
# 1

# %%
name = 'ubair  '

# %%
name = name.strip()

# %%
name
# Out:
# 'ubair'

# %%
name = name.capitalize()

# %%
name
# Out:
# 'Ubair'

# %%
import pandas as pd

# %%
df = pd.read_csv('2011.csv', header = 1, index_col = "Person ID")

# %%
df.head()
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
# 7395066    E12000001              H                   3                1    2
# 7395329    E12000001              H                   3                1    2
# 7394712    E12000001              H                   3                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
# 7395066      4               1        2                 1       1
# 7395329      2               1        2                 1       2
# 7394712      5               4        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
# 7395066               1         1                  1           6        11
# 7395329               1         2                  1           7         7
# 7394712               1         2                  1           1         4
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394816                       -9                          4
# 7394745                        4                          3
# 7395066                        3                          4
# 7395329                        3                          2
# 7394712                        3                          2

# %%
df.tail()
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7946020    W92000004              H                   1                1    1
# 7944310    W92000004              H                   3                1    1
# 7945374    W92000004              H                   3                1    1
# 7944768    W92000004              H                   1                1    2
# 7944959    W92000004              H                   2                1    2
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7946020      5               1        2                 1       4
# 7944310      3               1        2                 1       2
# 7945374      1               1        1                 1       1
# 7944768      8               5        2                 1       3
# 7944959      2               2        2                 1       2
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7946020               1         9                  1           8         8
# 7944310               1         1                  1           7         4
# 7945374               1         2                 -9          -9        -9
# 7944768               1         9                  5           9         2
# 7944959               1         1                  1           7         4
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7946020                        3                          3
# 7944310                        3                          4
# 7945374                       -9                         -9
# 7944768                       -9                          4
# 7944959                        1                          4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Region                       object
# Residence Type               object
# Family Composition            int64
# Population Base               int64
# Sex                           int64
# Age                           int64
# Marital Status                int64
# Student                       int64
# Country of Birth              int64
# Health                        int64
# Ethnic Group                  int64
# Religion                      int64
# Economic Activity             int64
# Occupation                    int64
# Industry                      int64
# Hours worked per week         int64
# Approximated Social Grade     int64
# dtype: object

# %%
df.shape
# Out:
# (569741, 17)

# %%
df.describe(include = 'all')
# Out:
#            Region Residence Type  Family Composition  Population Base  \
# count      569741         569741       569741.000000    569741.000000
# unique         10              2                 NaN              NaN
# top     E12000008              H                 NaN              NaN
# freq        88084         559087                 NaN              NaN
# mean          NaN            NaN            2.011870         1.018731
# std           NaN            NaN            2.358788         0.159058
# min           NaN            NaN           -9.000000         1.000000
# 25%           NaN            NaN            2.000000         1.000000
# 50%           NaN            NaN            2.000000         1.000000
# 75%           NaN            NaN            3.000000         1.000000
# max           NaN            NaN            6.000000         3.000000
#
#                   Sex            Age  Marital Status        Student  \
# count   569741.000000  569741.000000   569741.000000  569741.000000
# unique            NaN            NaN             NaN            NaN
# top               NaN            NaN             NaN            NaN
# freq              NaN            NaN             NaN            NaN
# mean         1.507550       3.978680        1.856201       1.777904
# std          0.499943       2.219494        1.125020       0.415655
# min          1.000000       1.000000        1.000000       1.000000
# 25%          1.000000       2.000000        1.000000       2.000000
# 50%          2.000000       4.000000        2.000000       2.000000
# 75%          2.000000       6.000000        2.000000       2.000000
# max          2.000000       8.000000        5.000000       2.000000
#
#         Country of Birth         Health   Ethnic Group       Religion  \
# count      569741.000000  569741.000000  569741.000000  569741.000000
# unique               NaN            NaN            NaN            NaN
# top                  NaN            NaN            NaN            NaN
# freq                 NaN            NaN            NaN            NaN
# mean            1.016239       1.658324       1.191250       2.419387
# std             1.153095       1.486598       1.391858       2.493064
# min            -9.000000      -9.000000      -9.000000      -9.000000
# 25%             1.000000       1.000000       1.000000       1.000000
# 50%             1.000000       2.000000       1.000000       2.000000
# 75%             1.000000       2.000000       1.000000       2.000000
# max             2.000000       5.000000       5.000000       9.000000
#
#         Economic Activity     Occupation       Industry  \
# count       569741.000000  569741.000000  569741.000000
# unique                NaN            NaN            NaN
# top                   NaN            NaN            NaN
# freq                  NaN            NaN            NaN
# mean             0.685597       1.240994       2.459844
# std              5.265465       6.521825       7.398945
# min             -9.000000      -9.000000      -9.000000
# 25%              1.000000      -9.000000      -9.000000
# 50%              1.000000       3.000000       4.000000
# 75%              5.000000       6.000000       8.000000
# max              9.000000       9.000000      12.000000
#
#         Hours worked per week  Approximated Social Grade
# count           569741.000000              569741.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# mean                -3.487095                   0.034130
# std                  5.887539                   4.862672
# min                 -9.000000                  -9.000000
# 25%                 -9.000000                   1.000000
# 50%                 -9.000000                   2.000000
# 75%                  3.000000                   3.000000
# max                  4.000000                   4.000000

# %%
df.columns
# Out:
# Index(['Region', 'Residence Type', 'Family Composition', 'Population Base',
#        'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'Approximated Social Grade'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
student_column = df['Student']

# %%
student_column
# Out:
# Person ID
# 7394816    2
# 7394745    2
# 7395066    2
# 7395329    2
# 7394712    2
#           ..
# 7946020    2
# 7944310    2
# 7945374    1
# 7944768    2
# 7944959    2
# Name: Student, Length: 569741, dtype: int64

# %%
students = df[df['Student'] == 1]

# %%
students
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394711    E12000001              H                   2                1    1
# 7394869    E12000001              H                   1                1    2
# 7395019    E12000001              H                   1                1    2
# 7394933    E12000001              H                   3                1    1
# 7394875    E12000001              H                   2                1    1
# ...              ...            ...                 ...              ...  ...
# 7946548    W92000004              H                   5                1    2
# 7944917    W92000004              H                   2                1    1
# 7946558    W92000004              H                   3                1    2
# 7944370    W92000004              H                   1                1    1
# 7945374    W92000004              H                   3                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394711      1               1        1                 1       1
# 7394869      2               1        1                 1       2
# 7395019      2               1        1                 1       2
# 7394933      2               1        1                 1       1
# 7394875      1               1        1                 1       1
# ...        ...             ...      ...               ...     ...
# 7946548      2               1        1                 1       2
# 7944917      1               1        1                 1       2
# 7946558      1               1        1                 1       1
# 7944370      3               3        1                 2       3
# 7945374      1               1        1                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394711               1         1                 -9          -9        -9
# 7394869               1         1                  4          -9        -9
# 7395019               1         1                  4           7         6
# 7394933               1         1                  6          -9        -9
# 7394875               1         2                 -9          -9        -9
# ...                 ...       ...                ...         ...       ...
# 7946548               2         1                  6          -9        -9
# 7944917               1         1                 -9          -9        -9
# 7946558               1         1                 -9          -9        -9
# 7944370               4         6                  4           9         6
# 7945374               1         2                 -9          -9        -9
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394711                       -9                         -9
# 7394869                       -9                          2
# 7395019                       -9                          2
# 7394933                       -9                          2
# 7394875                       -9                         -9
# ...                          ...                        ...
# 7946548                       -9                          2
# 7944917                       -9                         -9
# 7946558                       -9                         -9
# 7944370                        2                          2
# 7945374                       -9                         -9
#
# [126537 rows x 17 columns]

# %%
students.shape
# Out:
# (126537, 17)

# %%
students.shape[0]/df.shape[0]
# Out:
# 0.2220956539901464

# %%
widowed_students = students[students['Marital Status'] == 5]

# %%
widowed_students
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394525    E12000001              H                   3                1    1
# 7398965    E12000001              H                   1                1    1
# 7407173    E12000002              H                   5                1    2
# 7407164    E12000002              H                   2                1    2
# 7410876    E12000003              H                   1                1    1
# ...              ...            ...                 ...              ...  ...
# 7955293    W92000004              H                   5                1    2
# 7956702    W92000004              H                   5                1    2
# 7947048    W92000004              H                   3                1    1
# 7582925    E12000008              C                  -9                1    1
# 7678680    E12000008              C                  -9                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394525      2               5        1                 1       1
# 7398965      7               5        1                 1       3
# 7407173      5               5        1                 1       2
# 7407164      2               5        1                 1       3
# 7410876      7               5        1                 1       3
# ...        ...             ...      ...               ...     ...
# 7955293      4               5        1                 1       1
# 7956702      8               5        1                 1       2
# 7947048      1               5        1                 2       1
# 7582925      8               5        1                 1       3
# 7678680      2               5        1                 2       5
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394525               1         1                  4           5         5
# 7398965               1         2                  6           1         4
# 7407173               1         2                  4           1         5
# 7407164               1         5                  6          -9        -9
# 7410876               1         2                  4           1         3
# ...                 ...       ...                ...         ...       ...
# 7955293               1         1                  4           2        10
# 7956702               1         1                  4           2        10
# 7947048               3         3                 -9          -9        -9
# 7582925               1         2                  6           3         9
# 7678680               1         1                  4           6        10
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394525                       -9                          2
# 7398965                       -9                          2
# 7407173                        3                          2
# 7407164                       -9                          2
# 7410876                        3                          2
# ...                          ...                        ...
# 7955293                        3                          2
# 7956702                        3                          2
# 7947048                       -9                         -9
# 7582925                       -9                         -9
# 7678680                        4                         -9
#
# [109 rows x 17 columns]

# %%
widowed_students.shape
# Out:
# (109, 17)

# %%
widowed_students.to_csv('widowed_students.csv')
