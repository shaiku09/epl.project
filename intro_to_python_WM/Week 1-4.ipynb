# %%
import pandas as pd

# %%
df = pd.read_csv('2011.csv'), header = 1)
# Out:
#   File "<ipython-input-32-0c53d0b35847>", line 1
#     df = pd.read_csv('2011.csv'), header = 1)
#                                             ^
# SyntaxError: unmatched ')'

# %%
df
# Out:
#        For terms and conditions of use visit: http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/census-microdata/microdata-teaching-file/user-guide/index.html   \
# 0                                               Person ID
# 1                                                 7394816
# 2                                                 7394745
# 3                                                 7395066
# 4                                                 7395329
# ...                                                   ...
# 569737                                            7946020
# 569738                                            7944310
# 569739                                            7945374
# 569740                                            7944768
# 569741                                            7944959
#
#        Unnamed: 1      Unnamed: 2          Unnamed: 3       Unnamed: 4  \
# 0          Region  Residence Type  Family Composition  Population Base
# ...
