# %%
1+1
# Out:
# 2

# %%
c = [1, 2, 3]

# %%
type(c)
# Out:
# list

# %%
import pandas as pd

# %%
df = pd.read_csv('2011.csv', skiprows =1)

# %%
df
# Out:
#         Person ID     Region Residence Type  Family Composition  \
# 0         7394816  E12000001              H                   2
# 1         7394745  E12000001              H                   5
# 2         7395066  E12000001              H                   3
# 3         7395329  E12000001              H                   3
# 4         7394712  E12000001              H                   3
# ...           ...        ...            ...                 ...
# 569736    7946020  W92000004              H                   1
# 569737    7944310  W92000004              H                   3
# 569738    7945374  W92000004              H                   3
# 569739    7944768  W92000004              H                   1
# 569740    7944959  W92000004              H                   2
#
#         Population Base  Sex  Age  Marital Status  Student  Country of Birth  \
# 0                     1    2    6               2        2                 1
# ...

# %%
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
# 2    7395066  E12000001              H                   3                1
# 3    7395329  E12000001              H                   3                1
# 4    7394712  E12000001              H                   3                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
# 2    2    4               1        2                 1       1             1
# 3    2    2               1        2                 1       2             1
# 4    1    5               4        2                 1       1             1
#
# ...

# %%
df.describe()
# Out:
#           Person ID  Family Composition  Population Base            Sex  \
# count  5.697410e+05       569741.000000    569741.000000  569741.000000
# mean   7.679353e+06            2.011870         1.018731       1.507550
# std    1.644702e+05            2.358788         0.159058       0.499943
# min    7.394483e+06           -9.000000         1.000000       1.000000
# 25%    7.536918e+06            2.000000         1.000000       1.000000
# 50%    7.679353e+06            2.000000         1.000000       2.000000
# 75%    7.821788e+06            3.000000         1.000000       2.000000
# max    7.964223e+06            6.000000         3.000000       2.000000
#
#                  Age  Marital Status        Student  Country of Birth  \
# count  569741.000000   569741.000000  569741.000000     569741.000000
# mean        3.978680        1.856201       1.777904          1.016239
# std         2.219494        1.125020       0.415655          1.153095
# ...

# %%
df.shape
# Out:
# (569741, 18)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
