# %% [markdown]
# WEEK 3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('2011.csv', skiprows = 1, index_col = 'Person ID')

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade
# Person ID
# 7394816                       -9                          4
# 7394745                        4                          3

# %%
df['sqrt_age'] = df['Age'].apply(np.sqrt)

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000

# %%
df['age_student'] = df['Age']*df['Student']

# %%
df.head(2)
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000
#
#            age_student
# Person ID
# ...

# %%
test_list = [1, ['one', 2.0, 'three']]

# %%
test_list
# Out:
# [1, ['one', 2.0, 'three']]

# %%
test_list[1][0]
# Out:
# 'one'

# %%
# Dictionary = {key: value, key2 : value2}
#(curly brackets)

# %%
region_dict = {'E12000001': 'North East', 
'E12000002': 'North West', 
'E12000003': 'Yorkshire and the Humber', 
'E12000004': 'East Midlands', 
'E12000005': 'West Midlands', 
'E12000006': 'East of England', 
'E12000007': 'London', 
'E12000008': 'South East', 
'E12000009': 'South West',
'W92000004': 'Wales'}

religion_dict = {1: 'No religion', 
2: 'Christian', 
3: 'Buddhist', 
4: 'Hindu', 
5: 'Jewish', 
6: 'Muslim', 
7: 'Sikh', 
8: 'Other religion', 
9: 'Not stated',
-9: 'No code required'}


eco_dict = {1 : "Active: Employee", 
                 2 : "Active: Self-employed", 
                 3 : "Active: Unemployed", 
                 4 : "Active: Full-time student",
                 5 : "Inactive: Retired", 
                 6 : "Inactive: Student", 
                 7 : "Inactive: Looking after home", 
                 8 : "Inactive: Disabled",
                 9 : "Inactive: Other",
                 -9: "No code required"}

# %%
type(eco_dict)
# Out:
# dict

# %%
df['Region'] = df['Region'].map(region_dict)

# %%
df.head(2)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      2    6               2        2                 1       2
# 7394745      1    4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000
#
#            age_student
# Person ID
# ...

# %%
df
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
# 7395066    North East              H                   3                1
# 7395329    North East              H                   3                1
# 7394712    North East              H                   3                1
# ...               ...            ...                 ...              ...
# 7946020         Wales              H                   1                1
# 7944310         Wales              H                   3                1
# 7945374         Wales              H                   3                1
# 7944768         Wales              H                   1                1
# 7944959         Wales              H                   2                1
#
# ...

# %%
df['Religion_in_plain_English'] = df['Religion'].map(religion_dict)

# %%
df.head(2)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      2    6               2        2                 1       2
# 7394745      1    4               1        2                 1       1
#
#            Ethnic Group  Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816               1         2                  5           8         2
# 7394745               1         2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000
#
# ...

# %%
#df['is_female'] = df['Sex'].map(sex_dict)

# %%
sex_dict = {1: False, 2: True}

# %%
df['is_female'] = df['Sex'].map(sex_dict)

# %%
df.head(2)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  ...  \
# Person ID                                                               ...
# 7394816      2    6               2        2                 1       2  ...
# 7394745      1    4               1        2                 1       1  ...
#
#            Religion  Economic Activity  Occupation  Industry  \
# Person ID
# 7394816           2                  5           8         2
# 7394745           2                  1           8         6
#
#            Hours worked per week  Approximated Social Grade  sqrt_age  \
# Person ID
# 7394816                       -9                          4   2.44949
# 7394745                        4                          3   2.00000
# ...

# %%
df['Sex'], ['is_female']
# Out:
# (Person ID
#  7394816    2
#  7394745    1
#  7395066    2
#  7395329    2
#  7394712    1
#            ..
#  7946020    1
#  7944310    1
#  7945374    1
#  7944768    2
#  7944959    2
#  Name: Sex, Length: 569741, dtype: int64,
#  ['is_female'])

# %% [markdown]
# Sex differences among unemployed, employees and self-employed individuals.

# %%
df_eco_sex = df[['Sex', 'Economic Activity']] # Narrowed down the two columns to sex and Economic activity and added the headngs

# %%
df_eco_sex.head()
# Out:
#            Sex  Economic Activity
# Person ID
# 7394816      2                  5
# 7394745      1                  1
# 7395066      2                  1
# 7395329      2                  1
# 7394712      1                  1

# %%
gb_eco_sex = df_eco_sex.groupby(['Economic Activity', 'Sex']).size()

# %%
gb_eco_sex
# Out:
# Economic Activity  Sex
# -9                 1       57809
#                    2       54809
#  1                 1      107997
#                    2      108028
#  2                 1       28790
#                    2       11842
#  3                 1       10760
#                    2        7349
#  4                 1        6587
#                    2        7530
#  5                 1       40605
#                    2       56875
#  6                 1       12620
#                    2       12136
#  7                 1        1715
#                    2       16230
#  8                 1        9222
#                    2        8769
#  9                 1        4464
#                    2        5604
# dtype: int64

# %%
gb_eco_sex.plot(kind = 'bar', x = 'Economic Activity')
# Out:
# <Axes: xlabel='Economic Activity,Sex'>

# %%
df_age_sex = df[['Sex', 'Age',]]

# %%
df_age_sex
# Out:
#            Sex  Age
# Person ID
# 7394816      2    6
# 7394745      1    4
# 7395066      2    4
# 7395329      2    2
# 7394712      1    5
# ...        ...  ...
# 7946020      1    5
# 7944310      1    3
# 7945374      1    1
# 7944768      2    8
# 7944959      2    2
#
# [569741 rows x 2 columns]

# %%
gb_sex_age = df_age_sex.groupby(['Sex', 'Age']).size()

# %%
gb_sex_age
# Out:
# Sex  Age
# 1    1      54939
#      2      36743
#      3      38236
#      4      38969
#      5      38337
#      6      32207
#      7      23506
#      8      17632
# 2    1      51893
#      2      36042
#      3      37712
#      4      39672
#      5      39051
#      6      33459
#      7      25271
#      8      26072
# dtype: int64

# %%
gb_sex_age.plot(kind = 'bar', x = 'Sex', y = 'Age')
# Out:
# <Axes: xlabel='Sex,Age'>

# %%
df_wid_stud = df[(df['Student']==1) & (df['Marital Status'] == 5)]

# %%
df_wid_stud.shape
# Out:
# (109, 21)

# %% [markdown]
# WEEK 4

# %%
df.head()
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
# 7395066    North East              H                   3                1
# 7395329    North East              H                   3                1
# 7394712    North East              H                   3                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  ...  \
# Person ID                                                               ...
# 7394816      2    6               2        2                 1       2  ...
# 7394745      1    4               1        2                 1       1  ...
# 7395066      2    4               1        2                 1       1  ...
# 7395329      2    2               1        2                 1       2  ...
# ...

# %%
df['eco_activity'] = df['Economic Activity'].map(eco_dict)

# %%
df.head(2)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394816    North East              H                   2                1
# 7394745    North East              H                   5                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  ...  \
# Person ID                                                               ...
# 7394816      2    6               2        2                 1       2  ...
# 7394745      1    4               1        2                 1       1  ...
#
#            Economic Activity  Occupation  Industry  Hours worked per week  \
# Person ID
# 7394816                    5           8         2                     -9
# 7394745                    1           8         6                      4
#
#            Approximated Social Grade  sqrt_age  age_student  \
# Person ID
# 7394816                            4   2.44949           12
# ...

# %%
gb_eco_f = df.groupby(['eco_activity', 'is_female']).size().unstack() #   Groupby (object) is taking a portion of our data frame that is (eco and isfemale) as there are in square
                                                        # bracket which makes them a list AND we combine the result bysing .size.

# %%
gb_eco_f
# Out:
# is_female                      False   True
# eco_activity
# Active: Employee              107997  108028
# Active: Full-time student       6587    7530
# Active: Self-employed          28790   11842
# Active: Unemployed             10760    7349
# Inactive: Disabled              9222    8769
# Inactive: Looking after home    1715   16230
# Inactive: Other                 4464    5604
# Inactive: Retired              40605   56875
# Inactive: Student              12620   12136
# No code required               57809   54809

# %%
gb_eco_f.plot(kind = 'bar')
# Out:
# <Axes: xlabel='eco_activity'>

# %%
df_active = df[df['eco_activity'].isin(['Active: Employee', 'Active: Self-employed', 'Active: Unemployed'])]

# %%
df_active.head(10)
# Out:
#                Region Residence Type  Family Composition  Population Base  \
# Person ID
# 7394745    North East              H                   5                1
# 7395066    North East              H                   3                1
# 7395329    North East              H                   3                1
# 7394712    North East              H                   3                1
# 7394750    North East              H                   2                1
# 7394871    North East              H                   5                1
# 7394510    North East              H                   1                1
# 7395070    North East              H                   1                1
# 7394971    North East              H                   5                1
# 7395069    North East              H                   3                1
#
#            Sex  Age  Marital Status  Student  Country of Birth  Health  ...  \
# ...

# %%
gb_eco_f = df_active.groupby(['eco_activity', 'is_female']).size().unstack()

# %%
gb_eco_f.plot(kind = 'bar')
# Out:
# <Axes: xlabel='eco_activity'>

# %%
import seaborn as sns

# %%
df_down = df[['Age', 'Marital Status', 'Student', 'Economic Activity']] #Created a new data from that has only those 3 lists

# %%
df_down.head()
# Out:
#            Age  Marital Status  Student  Economic Activity
# Person ID
# 7394816      6               2        2                  5
# 7394745      4               1        2                  1
# 7395066      4               1        2                  1
# 7395329      2               1        2                  1
# 7394712      5               4        2                  1

# %%
df_down.corr() # This finds the correlation
# Out:
#                         Age  Marital Status   Student  Economic Activity
# Age                1.000000        0.639171  0.614706           0.666782
# Marital Status     0.639171        1.000000  0.390542           0.392210
# Student            0.614706        0.390542  1.000000           0.548938
# Economic Activity  0.666782        0.392210  0.548938           1.000000

# %%
sns.heatmap(df_down.corr(), annot = True)
# Out:
# <Axes: >

# %%
df_down.describe()
# Out:
#                  Age  Marital Status        Student  Economic Activity
# count  569741.000000   569741.000000  569741.000000      569741.000000
# mean        3.978680        1.856201       1.777904           0.685597
# std         2.219494        1.125020       0.415655           5.265465
# min         1.000000        1.000000       1.000000          -9.000000
# 25%         2.000000        1.000000       2.000000           1.000000
# 50%         4.000000        2.000000       2.000000           1.000000
# 75%         6.000000        2.000000       2.000000           5.000000
# max         8.000000        5.000000       2.000000           9.000000
