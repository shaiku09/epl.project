# %% [markdown]
# # WEEK 2

# %%
# comment to be made

# %%
a = 1

# %%
a
# Out:
# 1

# %%
name = 'ubair  '

# %%
name = name.strip()

# %%
name
# Out:
# 'ubair'

# %%
name = name.capitalize()

# %%
name
# Out:
# 'Ubair'

# %%
import pandas as pd

# %%
df = pd.read_csv('2011.csv', header = 1, index_col = "Person ID")

# %%
df.head()
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7394816    E12000001              H                   2                1    2
# 7394745    E12000001              H                   5                1    1
# 7395066    E12000001              H                   3                1    2
# 7395329    E12000001              H                   3                1    2
# 7394712    E12000001              H                   3                1    1
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7394816      6               2        2                 1       2
# 7394745      4               1        2                 1       1
# 7395066      4               1        2                 1       1
# 7395329      2               1        2                 1       2
# 7394712      5               4        2                 1       1
#
# ...

# %%
df.tail()
# Out:
#               Region Residence Type  Family Composition  Population Base  Sex  \
# Person ID
# 7946020    W92000004              H                   1                1    1
# 7944310    W92000004              H                   3                1    1
# 7945374    W92000004              H                   3                1    1
# 7944768    W92000004              H                   1                1    2
# 7944959    W92000004              H                   2                1    2
#
#            Age  Marital Status  Student  Country of Birth  Health  \
# Person ID
# 7946020      5               1        2                 1       4
# 7944310      3               1        2                 1       2
# 7945374      1               1        1                 1       1
# 7944768      8               5        2                 1       3
# 7944959      2               2        2                 1       2
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Region                       object
# Residence Type               object
# Family Composition            int64
# Population Base               int64
# Sex                           int64
# Age                           int64
# Marital Status                int64
# Student                       int64
# Country of Birth              int64
# Health                        int64
# Ethnic Group                  int64
# Religion                      int64
# Economic Activity             int64
# Occupation                    int64
# Industry                      int64
# Hours worked per week         int64
# Approximated Social Grade     int64
# dtype: object

# %%
df.shape
# Out:
# (569741, 17)

# %%
df.describe()
# Out:
#        Family Composition  Population Base            Sex            Age  \
# count       569741.000000    569741.000000  569741.000000  569741.000000
# mean             2.011870         1.018731       1.507550       3.978680
# std              2.358788         0.159058       0.499943       2.219494
# min             -9.000000         1.000000       1.000000       1.000000
# 25%              2.000000         1.000000       1.000000       2.000000
# 50%              2.000000         1.000000       2.000000       4.000000
# 75%              3.000000         1.000000       2.000000       6.000000
# max              6.000000         3.000000       2.000000       8.000000
#
#        Marital Status        Student  Country of Birth         Health  \
# count   569741.000000  569741.000000     569741.000000  569741.000000
# mean         1.856201       1.777904          1.016239       1.658324
# std          1.125020       0.415655          1.153095       1.486598
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Residence Type', 'Family Composition', 'Population Base',
#        'Sex', 'Age', 'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'Approximated Social Grade'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index
